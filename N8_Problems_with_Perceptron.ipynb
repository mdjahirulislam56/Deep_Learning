# %% [markdown]
# ### Limitation of Perceptron
#
# The perceptron **cannot classify non-linearly separable data**. For example, it cannot solve problems like the XOR problem, where data classes cannot be separated by a straight line. This limitation arises because the perceptron’s decision boundary is always linear. To handle non-linear data, more complex models like multi-layer perceptrons (MLPs) with hidden layers or other advanced neural networks are needed.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['X1'] = [1,1,0,0]
or_data['X2'] = [1,0,1,0]
or_data['Y'] = [1,1,1,0]

# %%
and_data['X1'] = [1,1,0,0]
and_data['X2'] = [1,0,1,0]
and_data['Y'] = [1,0,0,0]

# %%
xor_data['X1'] = [1,1,0,0]
xor_data['X2'] = [1,0,1,0]
xor_data['Y'] = [0,1,1,0]

# %%
and_data
# Out:
#    X1  X2  Y
# 0   1   1  1
# 1   1   0  0
# 2   0   1  0
# 3   0   0  0

# %%
or_data
# Out:
#    X1  X2  Y
# 0   1   1  1
# 1   1   0  1
# 2   0   1  1
# 3   0   0  0

# %%
xor_data
# Out:
#    X1  X2  Y
# 0   1   1  0
# 1   1   0  1
# 2   0   1  1
# 3   0   0  0

# %%
plt.figure(figsize=(10,7))
plt.scatter(or_data['X1'], or_data['X2'], c=or_data['Y'], cmap='viridis',s=400)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('OR Data')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(and_data['X1'], and_data['X2'], c=and_data['Y'], cmap='viridis',s=400)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('AND Data')
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter(xor_data['X1'], xor_data['X2'], c=xor_data['Y'], cmap='viridis',s=400)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('OR Data')
plt.show()

# %%
from sklearn.linear_model import Perceptron

or_model = Perceptron()
and_model = Perceptron()
xor_model = Perceptron()

or_model.fit(or_data.iloc[:,0:2].values, or_data.iloc[:,-1].values)
and_model.fit(and_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
xor_model.fit(xor_data.iloc[:,0:2].values, xor_data.iloc[:,-1].values)

print(or_model.coef_,or_model.intercept_)
print(and_model.coef_,and_model.intercept_)
print(xor_model.coef_,xor_model.intercept_)
# Out:
# [[2. 2.]] [-1.]
# [[2. 2.]] [-2.]
# [[0. 0.]] [0.]

# %%
x = np.linspace(-1,1,5)
y = - x + (1/2)
plt.figure(figsize=(10,7))
plt.scatter(or_data['X1'], or_data['X2'], c=or_data['Y'], cmap='viridis',s=400)
plt.plot(x,y)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('OR Data')
plt.show()

# %%
x = np.linspace(-1,1,5)
y = - x + 1
plt.figure(figsize=(10,7))
plt.scatter(and_data['X1'], and_data['X2'], c=and_data['Y'], cmap='viridis',s=200)
plt.plot(x,y)
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('AND Data')
plt.show()

# %%
x = np.linspace(-0.5, 1.5, 100)
y = -(0/0) * x - (0/0) #Cannot plot decision boundary: XOR is not linearly separable by a single-layer perceptron.
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[42], line 2
#       1 x = np.linspace(-0.5, 1.5, 100)
# ----> 2 y = -(0/0) * x - (0/0) #Cannot plot decision boundary: XOR is not linearly separable by a single-layer perceptron.
#
# ZeroDivisionError: division by zero

# %% [markdown]
# We can visualize this in this website more clearly. We will notice that the epochs will continue increasing but the model will never converge...
#
# https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.42733&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false
